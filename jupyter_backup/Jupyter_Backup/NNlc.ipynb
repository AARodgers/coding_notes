# %% [markdown]
# # Amanda Rodgers
# # April 27, 2024
# # Women's Directory Analytics

# %%
import sqlite3
import pandas as pd

# %%
import psycopg2
from sqlalchemy import create_engine

# %%
engine = create_engine('postgresql://localhost/womens_directory_dump')

# %%
import pandas as pd

# %%
query = "SELECT * FROM orgs limit 5"
df = pd.read_sql_query(query, engine)
df
# Out:
#     id                                               name  \
# 0    1                                   Healthy Futures©
# 1  107                                    CommunityWorks©
# 2   31  The Goddard School© For Early Childhood Develo...
# 3  189                                  Hope Communities©
# 4  190                                      Shared Touch©
#
#                                website  \
# 0  https://healthyfuturesforwomen.com/
# 1            https://www.commwrks.org/
# 2       https://www.goddardschool.com/
# 3          https://hopecommunities.org
# 4             https://sharedtouch1.com
#
#                                                 desc  \
# 0  Healthy Futures© is a Colorado-based \r\nwomen...
# 1  CommunityWorks© is a job and employment assist...
# 2  The Goddard School© for Early Childhood Develo...
# 3  Hope Communities© is a non-profit organization...
# 4  Shared Touch© is a home healthcare services or...
#
#                   created_at                 updated_at submission_id  visible
# 0 2021-04-25 19:02:07.573389 2022-10-30 21:57:01.222390          None     True
# 1 2021-06-26 21:43:31.694062 2022-12-04 23:10:42.765470          None     True
# 2 2021-05-12 19:09:45.626903 2022-12-26 16:57:21.497458          None     True
# 3 2022-12-28 17:06:22.702322 2022-12-28 17:15:23.486999          None     True
# 4 2022-12-28 18:02:15.428251 2022-12-28 18:02:15.428251          None     True
