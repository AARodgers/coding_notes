# %%
from pyvis.network import Network
net = Network()

# %%
net.add_node(1, label="Node 1")
net.add_node(2)

nodes = ["a", "b", "c", "d"]
net.add_nodes(nodes) # node ids and labels = ["a", "b", "c", "d"]
net.add_nodes("hello") # node ids and labels = ["h", "e", "l", "o"]

# %%
net.get_node("c")
# Out:
# {'color': '#97c2fc', 'id': 'c', 'label': 'c', 'shape': 'dot'}

# %%
g = Network()
g.add_nodes([1,2,3], value=[10, 100, 400],
                         title=['I am node 1', 'node 2 here', 'and im node 3'],
                         x=[21.4, 54.2, 11.2],
                         y=[100.2, 23.54, 32.1],
                         label=['NODE 1', 'NODE 2', 'NODE 3'],
                         color=['#00ff1e', '#162347', '#dd4b39'])

# %%
pip install pyvis==0.3.1
# Out:
# Collecting pyvis==0.3.1
#   Downloading pyvis-0.3.1.tar.gz (748 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 748.9/748.9 kB 11.6 MB/s eta 0:00:00a 0:00:01
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: jinja2>=2.9.6 in /opt/anaconda3/lib/python3.11/site-packages (from pyvis==0.3.1) (3.1.3)
# Requirement already satisfied: networkx>=1.11 in /opt/anaconda3/lib/python3.11/site-packages (from pyvis==0.3.1) (3.3)
# Requirement already satisfied: ipython>=5.3.0 in /opt/anaconda3/lib/python3.11/site-packages (from pyvis==0.3.1) (8.20.0)
# Requirement already satisfied: jsonpickle>=1.4.1 in /opt/anaconda3/lib/python3.11/site-packages (from pyvis==0.3.1) (3.2.2)
# Requirement already satisfied: decorator in /opt/anaconda3/lib/python3.11/site-packages (from ipython>=5.3.0->pyvis==0.3.1) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /opt/anaconda3/lib/python3.11/site-packages (from ipython>=5.3.0->pyvis==0.3.1) (0.18.1)
# Requirement already satisfied: matplotlib-inline in /opt/anaconda3/lib/python3.11/site-packages (from ipython>=5.3.0->pyvis==0.3.1) (0.1.6)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /opt/anaconda3/lib/python3.11/site-packages (from ipython>=5.3.0->pyvis==0.3.1) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in /opt/anaconda3/lib/python3.11/site-packages (from ipython>=5.3.0->pyvis==0.3.1) (2.15.1)
# Requirement already satisfied: stack-data in /opt/anaconda3/lib/python3.11/site-packages (from ipython>=5.3.0->pyvis==0.3.1) (0.2.0)
# Requirement already satisfied: traitlets>=5 in /opt/anaconda3/lib/python3.11/site-packages (from ipython>=5.3.0->pyvis==0.3.1) (5.7.1)
# Requirement already satisfied: pexpect>4.3 in /opt/anaconda3/lib/python3.11/site-packages (from ipython>=5.3.0->pyvis==0.3.1) (4.8.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/anaconda3/lib/python3.11/site-packages (from jinja2>=2.9.6->pyvis==0.3.1) (2.1.3)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /opt/anaconda3/lib/python3.11/site-packages (from jedi>=0.16->ipython>=5.3.0->pyvis==0.3.1) (0.8.3)
# Requirement already satisfied: ptyprocess>=0.5 in /opt/anaconda3/lib/python3.11/site-packages (from pexpect>4.3->ipython>=5.3.0->pyvis==0.3.1) (0.7.0)
# Requirement already satisfied: wcwidth in /opt/anaconda3/lib/python3.11/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=5.3.0->pyvis==0.3.1) (0.2.5)
# Requirement already satisfied: executing in /opt/anaconda3/lib/python3.11/site-packages (from stack-data->ipython>=5.3.0->pyvis==0.3.1) (0.8.3)
# Requirement already satisfied: asttokens in /opt/anaconda3/lib/python3.11/site-packages (from stack-data->ipython>=5.3.0->pyvis==0.3.1) (2.0.5)
# Requirement already satisfied: pure-eval in /opt/anaconda3/lib/python3.11/site-packages (from stack-data->ipython>=5.3.0->pyvis==0.3.1) (0.2.2)
# Requirement already satisfied: six in /opt/anaconda3/lib/python3.11/site-packages (from asttokens->stack-data->ipython>=5.3.0->pyvis==0.3.1) (1.16.0)
# Building wheels for collected packages: pyvis
#   Building wheel for pyvis (setup.py) ... done
#   Created wheel for pyvis: filename=pyvis-0.3.1-py3-none-any.whl size=755830 sha256=28e579d491f275ee2a4250f8636183c1a0f4803d00485bbad08e8cb607682b17
#   Stored in directory: /Users/amandarodgers/Library/Caches/pip/wheels/83/76/b0/8be6263eaa807c52b432b8e4d8eb2629d21b856215ae6d7024
# Successfully built pyvis
# Installing collected packages: pyvis
#   Attempting uninstall: pyvis
#     Found existing installation: pyvis 0.3.2
#     Uninstalling pyvis-0.3.2:
#       Successfully uninstalled pyvis-0.3.2
# Successfully installed pyvis-0.3.1
# Note: you may need to restart the kernel to use updated packages.

# %%
import pyvis
pyvis.__version__
# Out:
# '0.3.1'

# %%
from pyvis.network import Network
import networkx as nx

nx_graph = nx.cycle_graph(10)

nx_graph.nodes[1]['title'] = 'Number 1'
nx_graph.nodes[1]['group'] = 1
nx_graph.nodes[3]['title'] = 'I belong to a different group!'
nx_graph.nodes[3]['group'] = 10
nx_graph.add_node(20, size=20, title='couple', group=2)
nx_graph.add_node(21, size=15, title='couple', group=2)
nx_graph.add_edge(20, 21, weight=5)
nx_graph.add_node(25, size=25, label='lonely', title='lonely node', group=3)

nt = Network('500px', '500px', notebook=True)

# populates the nodes and edges data structures
nt.from_nx(nx_graph)
nt.show('nx.html')
# Out:
# Local cdn resources have problems on chrome/safari when used in jupyter-notebook.
#         <iframe
#             width="500px"
#             height="500px"
#             src="nx.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
